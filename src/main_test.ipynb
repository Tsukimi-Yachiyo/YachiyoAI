# %%
import sys,os
import ipynbname as ipynbname

nb_path = ipynbname.path()
current_dir = os.path.dirname(nb_path)
# 把 src 文件夹加入搜索路径，让 import api 直接生效
sys.path.append(current_dir)

# 切换工作目录
os.chdir("\\".join(current_dir.split("\\")[:-2]))
import main

# %%
service = main.Service()
# Out:
# 2026-04-06 16:41:20,497 - persistent.yml - INFO - YAML文件加载成功，共加载10个键
# 2026-04-06 16:41:20,497 - persistent.json - INFO - JSON文件加载成功，共加载2个键
# 2026-04-06 16:41:21,092 - llm.model - INFO - 模型服务初始化
# 2026-04-06 16:41:21,162 - persistent.db_history - INFO -  长期对话历史记录数据库表初始化完成
# 2026-04-06 16:41:21,234 - persistent.db_api_depository - INFO -  API仓库数据库表初始化完成

# %%
service.get_graph()

# %%
import asyncio

# %%
await service.chat("彩叶是谁",1)
# Out:
# 2026-04-06 16:49:38,762 - agents.tool.is_persona_out - INFO - has_characters: True, has_self_keywords: False, has_regex_patterns: False, has_blacklist_keywords: False
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 await service.chat("彩叶是谁",1)
#       2
#
# File D:\IT\program\Yachiyo\YachiyoAI\src\main.py:52, in Service.chat(self, prompt, conversationId)
#      50 async def chat(self, prompt: str, conversationId: int):
#      51     config = {"configurable": {"thread_id": conversationId}}
# ---> 52     result = await self.state.ainvoke(
#      53         {"messages": [("user",prompt)],
#      54         "query": prompt,},
#      55         config = config)
#      56     return result["messages"][-1].content
#
# ...
