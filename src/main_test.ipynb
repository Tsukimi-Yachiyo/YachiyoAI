# %%
import sys,os
import ipynbname as ipynbname

nb_path = ipynbname.path()
current_dir = os.path.dirname(nb_path)
# 把 src 文件夹加入搜索路径，让 import api 直接生效
sys.path.append(current_dir)

# 切换工作目录
os.chdir("\\".join(current_dir.split("\\")[:-2]))
import main

# %%
service = main.Service()
# Out:
# 2026-04-06 21:50:07,302 - persistent.yml - ERROR - YAML文件加载失败: [WinError 3] 系统找不到指定的路径。: 'resource/config/yaml'
# 2026-04-06 21:50:07,303 - persistent.json - ERROR - JSON文件加载失败: [WinError 3] 系统找不到指定的路径。: 'resource/json'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 service = main.Service()
#
# File D:\IT\program\Yachiyo\YachiyoAI\src\main.py:33, in Service.__init__(self)
#
# File D:\IT\program\Yachiyo\YachiyoAI\src\llm\model.py:66, in model_init()
#      64 def model_init():
#      65     global model_service
# ---> 66     model_service = ModelDepository()
#      67     logger.info("模型服务初始化")
#
# File D:\IT\program\Yachiyo\YachiyoAI\src\llm\model.py:16, in ModelDepository.__init__(self)
#      12 def __init__(self):
#      13     self.models = []
#      14     self.compress_model = ChatOpenAI(
#      15         model=settings.COMPRESS_MODEL_NAME,
# ---> 16         api_key=yml.all_yaml.get("llm.api_key"),
#      17         base_url=settings.BASE_URL,
#      18         temperature=0.7
#      19     )
#      20     self.embeddings_model = OpenAIEmbeddings(
#      21         model=settings.EMBEDDINGS_MODEL_NAME,
#      22         api_key=yml.all_yaml.get("llm.api_key"),
#      23         base_url=settings.BASE_URL
#      24     )
#      25     self.models.append(
#      26         ChatOpenAI(
#      27             model=settings.MODEL_NAME,
#    (...)     31         )
#      32     )
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
service.get_graph()

# %%
await service.chat("彩叶是谁",1)
