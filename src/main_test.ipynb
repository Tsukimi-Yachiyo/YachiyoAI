# %%
import sys,os
# 把 src 文件夹加入搜索路径，让 import api 直接生效
sys.path.append(r"D:\IT\program\Yachiyo\YachiyoAI\src")

# 切换工作目录
os.chdir(r"D:\IT\program\Yachiyo\YachiyoAI")
import main
# Out:
# ✅ Peewee 数据库表初始化完成

# %%
service = main.Service()

# %%
service.get_graph()
