# %%
import sys
sys.path.append("D:/IT/program/Yachiyo/YachiyoAI")
import main
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[5], line 3
#       1 import sys
#       2 sys.path.append("D:/IT/program/Yachiyo/YachiyoAI")
# ----> 3 import main
#
# File D:\IT\program\Yachiyo\YachiyoAI\src\main.py:8
#       4 import api
#       7 # 导入模型
# ----> 8 from src.llm.model import model as llm_model
#      10 # 导入数据库服务
#      11 from src.persistent.db_history import history_service
#
# File D:\IT/program/Yachiyo/YachiyoAI\src\llm\model.py:2
#       1 from langchain_openai import ChatOpenAI
# ----> 2 from src.config import settings
#       5 class ModelDepository:
#       7     def __init__(self):
#
# File D:\IT/program/Yachiyo/YachiyoAI\src\config.py:21
#      15     BASE_URL: str
#      17     model_config = SettingsConfigDict(
#      18         env_file=".env",
#      19         env_file_encoding="utf-8")
# ---> 21 settings = Settings()
#
# ...

# %%
service = main.Service()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 service = main.Service()
#
# NameError: name 'main' is not defined

# %%
service.get_graph()
